# %%
enterprise account

Looked into the difference between the different types of compute - 
- All Purpose | 
- Serverless | 
- Serverless Compute | 
- Job 

each with a different Data Bricks Unit which costs different in each compute 

all purpose (interactive, collabrative)
job compute (orchestration)  

serverless 
serverless sql wh
