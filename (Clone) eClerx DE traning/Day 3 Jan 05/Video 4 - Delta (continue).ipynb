-- %%
create table dev.demo.emp(id int, name string)

-- %%
insert into dev.demo.emp values (1,'Hrishav');

-- %%
desc extended dev.demo.emp

-- %%
desc detail dev.demo.emp

-- %%
desc history dev.demo.emp

-- %%
create table emp_ice(id int, name string, age int) using iceberg

-- %%
create table emp_hudi(id int, name string, age int) using hudi

-- %% [markdown]
-- https://datamasterconsultingin-my.sharepoint.com/personal/naval_thedatamaster_in/_layouts/15/onedrive.aspx?id=%2Fpersonal%2Fnaval%5Fthedatamaster%5Fin%2FDocuments%2FEclerx%2Fdbc%20files%2Feclerx%5Fde%5F22%5Fsept&ga=1
