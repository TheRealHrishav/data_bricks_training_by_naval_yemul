# %%
"""Control Pannel (databricks account) : databricks software
1. compute Orchestration
2. utitlity cataloge (Governace)
3. jobs and pipeline
4. ui
5. notebooks and queries
6. serverless compute 
etc and etc 

Data Pannel (cloud account) (azure, aws , GCP)
1. classic compute
2. storage"""
