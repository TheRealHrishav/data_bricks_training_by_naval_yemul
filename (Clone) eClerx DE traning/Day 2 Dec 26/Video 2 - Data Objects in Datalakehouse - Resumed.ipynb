# %%
"""Data bricks has 3 level namespace
Metastore -> Catalog -> Schema |-> Table
                               |-> View
                               |-> Function - (includes Model)
                               |-> Volume
                               |-> sp - (stored procedure)

Done using 
- UI
- SQL Syntax

CVs, JSONs, Parques, Avros, Delta, Iceberg, XML and XLXS all these formats exists """

# %%
# %sql
use catalog dev;

# %%
# %sql
create schema demo;

# %%
# %sql
create table if not exists dev.demo.sample (id int, name string)

# %%
# %sql
insert into dev.demo.sample values(1, 'Hrishav')

# %%
# %sql
select * from dev.demo.sample

# %%
# %sql
create or replace table dev.demo.sales_transactions_copy as  -- create table as select (CTAS)
select * from samples.bakehouse.sales_transactions

# %%
# %sql
select sum(totalPrice) from dev.demo.sales_transactions_copy
