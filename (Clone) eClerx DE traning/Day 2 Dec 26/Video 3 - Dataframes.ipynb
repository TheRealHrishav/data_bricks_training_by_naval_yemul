# %% [markdown]
# Lazy evalution
#
# Transform
# i. Read
#
# Action
# i. show
# ii. display
# iii. write

# %%
df = spark.read.csv("/Volumes/dev/demo/raw/input/financial_dataset.csv",header=True)

# %%
df.show()

# %%
df.write.mode('overwrite').saveAsTable("dev.demo.finacial_pyspark")
